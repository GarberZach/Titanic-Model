# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
os.chdir(r'C:\Users\mgarb\Desktop\Jupyter NoteBook')
df = pd.read_csv('titanic.csv')
df.keys()
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare'],
#       dtype='object')

# %%
df = df.drop(columns = ["Name","Pclass"])

# %%
df = df.replace('male', 0)
df = df.replace('female', 1)

# %%
import numpy as np

# %%
fare_data = np.load(r'C:\Users\mgarb\Desktop\sublimePy\npy\fare_array.npy')

# %%
fare_data_df = pd.DataFrame(fare_data)

# %%
fare_data_df
# Out:
#             0
# 0   -0.503586
# 1    0.783412
# 2   -0.490020
# 3    0.417948
# 4   -0.487507
# ..        ...
# 882 -0.388018
# 883 -0.046336
# 884 -0.177984
# 885 -0.046336
# 886 -0.493537
#
# [887 rows x 1 columns]

# %%
df["fare_data"] = fare_data_df

# %%
df.drop(columns = ["Fare"])
# Out:
#      Survived  Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 0           0    0  22.0                        1                        0
# 1           1    1  38.0                        1                        0
# 2           1    1  26.0                        0                        0
# 3           1    1  35.0                        1                        0
# 4           0    0  35.0                        0                        0
# ..        ...  ...   ...                      ...                      ...
# 882         0    0  27.0                        0                        0
# 883         1    1  19.0                        0                        0
# 884         0    1   7.0                        1                        2
# 885         1    0  26.0                        0                        0
# 886         0    0  32.0                        0                        0
#
#      fare_data
# 0    -0.503586
# 1     0.783412
# 2    -0.490020
# ...

# %%
labels = pd.DataFrame()

# %%
labels = df["Survived"]

# %%
labels
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 882    0
# 883    1
# 884    0
# 885    1
# 886    0
# Name: Survived, Length: 887, dtype: int64

# %%
df.drop(columns = ['Fare'])
# Out:
#      Survived  Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 0           0    0  22.0                        1                        0
# 1           1    1  38.0                        1                        0
# 2           1    1  26.0                        0                        0
# 3           1    1  35.0                        1                        0
# 4           0    0  35.0                        0                        0
# ..        ...  ...   ...                      ...                      ...
# 882         0    0  27.0                        0                        0
# 883         1    1  19.0                        0                        0
# 884         0    1   7.0                        1                        2
# 885         1    0  26.0                        0                        0
# 886         0    0  32.0                        0                        0
#
#      fare_data
# 0    -0.503586
# 1     0.783412
# 2    -0.490020
# ...

# %%
age_data = np.load(r'C:\Users\mgarb\Desktop\sublimePy\npy\age_data.npy')

# %%
age_data_df = pd.DataFrame(age_data)

# %%
age_data_df
# Out:
#             0
# 0   -0.529366
# 1    0.604265
# 2   -0.245958
# 3    0.391709
# 4    0.391709
# ..        ...
# 882 -0.175106
# 883 -0.741922
# 884 -1.592145
# 885 -0.245958
# 886  0.179153
#
# [887 rows x 1 columns]

# %%
df["age_data"] = age_data_df

# %%
df = df.drop(columns = ["Fare", "Age "])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-6a8170d76a10> in <module>
# ----> 1 df = df.drop(columns = ["Fare", "Age", "Survived"])
#
# c:\users\mgarb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# c:\users\mgarb\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
# ...

# %%
df = df.drop(columns = ["Survived"])

# %%
df["Survived"] = labels

# %%
corr_matrix = titanic_df_with_labels.corr()
corr_matrix['Survived'].sort_values(ascending = False)
# Out:
# Survived                   1.000000
# Sex                        0.542152
# fare_data                  0.256179
# Parents/Children Aboard    0.080097
# Siblings/Spouses Aboard   -0.037082
# age_data                  -0.059665
# Name: Survived, dtype: float64

# %%
df
# Out:
#      Survived     Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 0           0    male  22.0                        1                        0
# 1           1  female  38.0                        1                        0
# 2           1  female  26.0                        0                        0
# 3           1  female  35.0                        1                        0
# 4           0    male  35.0                        0                        0
# ..        ...     ...   ...                      ...                      ...
# 882         0    male  27.0                        0                        0
# 883         1  female  19.0                        0                        0
# 884         0  female   7.0                        1                        2
# 885         1    male  26.0                        0                        0
# 886         0    male  32.0                        0                        0
#
#         Fare
# 0     7.2500
# ...

# %%
import os
os.chdir(r'C:\Users\mgarb\Desktop\Jupyter NoteBook\pickled_df')

# %%
df.to_pickle('./titanic.pkl')

# %%
titanic_df_with_labels = pd.read_pickle(r'C:\Users\mgarb\Desktop\Jupyter NoteBook\pickled_df\titanic.pkl')

# %%
titanic_df_with_labels
# Out:
#      Sex  Siblings/Spouses Aboard  Parents/Children Aboard  fare_data  \
# 0      0                        1                        0  -0.503586
# 1      1                        1                        0   0.783412
# 2      1                        0                        0  -0.490020
# 3      1                        1                        0   0.417948
# 4      0                        0                        0  -0.487507
# ..   ...                      ...                      ...        ...
# 882    0                        0                        0  -0.388018
# 883    1                        0                        0  -0.046336
# 884    1                        1                        2  -0.177984
# 885    0                        0                        0  -0.046336
# 886    0                        0                        0  -0.493537
#
#      age_data  Survived
# 0   -0.529366         0
# 1    0.604265         1
# 2   -0.245958         1
# 3    0.391709         1
# ...

# %%
labels = titanic_df_with_labels["Survived"]

# %%
titanic_df
# Out:
#      Sex  Siblings/Spouses Aboard  Parents/Children Aboard  fare_data  \
# 0      0                        1                        0  -0.503586
# 1      1                        1                        0   0.783412
# 2      1                        0                        0  -0.490020
# 3      1                        1                        0   0.417948
# 4      0                        0                        0  -0.487507
# ..   ...                      ...                      ...        ...
# 882    0                        0                        0  -0.388018
# 883    1                        0                        0  -0.046336
# 884    1                        1                        2  -0.177984
# 885    0                        0                        0  -0.046336
# 886    0                        0                        0  -0.493537
#
#      age_data
# 0   -0.529366
# 1    0.604265
# 2   -0.245958
# 3    0.391709
# 4    0.391709
# ..        ...
# 882 -0.175106
# ...

# %%
import numpy as np
df_numpy = titanic_df.to_numpy()
labels_numpy = labels.to_numpy()

# %%
labels_numpy.ndim
# Out:
# 1

# %%
import numpy as np
labels_numpy = labels_numpy.reshape(-1, 1)

# %%
X_train, X_test, y_train, y_test = df_numpy[:710], df_numpy[710:], labels_numpy[:710], labels_numpy[710:]

# %%
os.chdir(r'C:\Users\mgarb\Desktop\ds_data')

# %%
np.save('tX_train',X_train)

# %%
np.save('tX_test',X_test)

# %%
np.save('ty_train', y_train)

# %%
np.save('ty_test', y_test)
